# %% [markdown]
# # Module 1 Problem Set

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 1</b></div>
#
# Graph the following:
# $$ y = -2x + 4 $$

# %% [markdown]
# Install python packages

# %%
# !pip install matplotlib numpy sympy
# Out:
# Requirement already satisfied: matplotlib in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: numpy in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (2.3.5)
# Collecting sympy
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: six>=1.5 in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [sympy]32m1/2 [sympy]
# Successfully installed mpmath-1.3.0 sympy-1.14.0

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/pvishnoi/PycharmProjects/msds-northwestern-projects-2025/.env/lib/python3.13/site-packages (24.3.1)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 394.9 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-25.3

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the equation function
def equation(x):
    return -2*x + 4

# Generate x values from -5 to 5 (this can be adjusted)
x = np.linspace(-5, 5, 100)
print(x)
# Calculate corresponding y values using the equation function
y = equation(x)
print(y)

# Add x-axis and y-axis lines
plt.axhline(y=0, color='green', linewidth=2)  # Horizontal line at y=0
plt.axvline(x=0, color='green', linewidth=2)  # Vertical line at x=0

# Plot the graph
plt.plot(x, y, label="y = -2x + 4")

# Add labels and title
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Graph of y = -2x + 4")

# Add a grid for better readability
plt.grid(True)

# Add a legend
plt.legend()

# Show the graph
plt.show()
# Out:
# [-5.         -4.8989899  -4.7979798  -4.6969697  -4.5959596  -4.49494949
#  -4.39393939 -4.29292929 -4.19191919 -4.09090909 -3.98989899 -3.88888889
#  -3.78787879 -3.68686869 -3.58585859 -3.48484848 -3.38383838 -3.28282828
#  -3.18181818 -3.08080808 -2.97979798 -2.87878788 -2.77777778 -2.67676768
#  -2.57575758 -2.47474747 -2.37373737 -2.27272727 -2.17171717 -2.07070707
#  -1.96969697 -1.86868687 -1.76767677 -1.66666667 -1.56565657 -1.46464646
#  -1.36363636 -1.26262626 -1.16161616 -1.06060606 -0.95959596 -0.85858586
#  -0.75757576 -0.65656566 -0.55555556 -0.45454545 -0.35353535 -0.25252525
#  -0.15151515 -0.05050505  0.05050505  0.15151515  0.25252525  0.35353535
#   0.45454545  0.55555556  0.65656566  0.75757576  0.85858586  0.95959596
#   1.06060606  1.16161616  1.26262626  1.36363636  1.46464646  1.56565657
#   1.66666667  1.76767677  1.86868687  1.96969697  2.07070707  2.17171717
#   2.27272727  2.37373737  2.47474747  2.57575758  2.67676768  2.77777778
#   2.87878788  2.97979798  3.08080808  3.18181818  3.28282828  3.38383838
#   3.48484848  3.58585859  3.68686869  3.78787879  3.88888889  3.98989899
#   4.09090909  4.19191919  4.29292929  4.39393939  4.49494949  4.5959596
#   4.6969697   4.7979798   4.8989899   5.        ]
# [14.         13.7979798  13.5959596  13.39393939 13.19191919 12.98989899
#  12.78787879 12.58585859 12.38383838 12.18181818 11.97979798 11.77777778
#  11.57575758 11.37373737 11.17171717 10.96969697 10.76767677 10.56565657
#  10.36363636 10.16161616  9.95959596  9.75757576  9.55555556  9.35353535
#   9.15151515  8.94949495  8.74747475  8.54545455  8.34343434  8.14141414
#   7.93939394  7.73737374  7.53535354  7.33333333  7.13131313  6.92929293
#   6.72727273  6.52525253  6.32323232  6.12121212  5.91919192  5.71717172
#   5.51515152  5.31313131  5.11111111  4.90909091  4.70707071  4.50505051
#   4.3030303   4.1010101   3.8989899   3.6969697   3.49494949  3.29292929
#   3.09090909  2.88888889  2.68686869  2.48484848  2.28282828  2.08080808
#   1.87878788  1.67676768  1.47474747  1.27272727  1.07070707  0.86868687
#   0.66666667  0.46464646  0.26262626  0.06060606 -0.14141414 -0.34343434
#  -0.54545455 -0.74747475 -0.94949495 -1.15151515 -1.35353535 -1.55555556
#  -1.75757576 -1.95959596 -2.16161616 -2.36363636 -2.56565657 -2.76767677
#  -2.96969697 -3.17171717 -3.37373737 -3.57575758 -3.77777778 -3.97979798
#  -4.18181818 -4.38383838 -4.58585859 -4.78787879 -4.98989899 -5.19191919
#  -5.39393939 -5.5959596  -5.7979798  -6.        ]

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 4: </b></div>
#
# Given two points (3,-7) and (10,2) on a line, answer the following questions.
#
#  on a line, answer the following questions.
#
# a.) What is the slope?
#
# b.) What is the y-intercept?
#
# c.) What is the slope-intercept form of the equation?

# %%
# Given points
x1, y1 = 3, -7
x2, y2 = 10, 2

# Calculate the slope
slope = (y2 - y1) / (x2 - x1)

# Calculate the y-intercept
y_intercept = y1 - slope * x1

# Write the slope-intercept form of the equation
equation = f"y = {slope:.2f}x + {y_intercept:.2f}"

# Display the results
print("Slope:", slope)
print("Y-intercept:", y_intercept)
print("Slope-intercept form of the equation:", equation)
# Out:
# Slope: 1.2857142857142858
# Y-intercept: -10.857142857142858
# Slope-intercept form of the equation: y = 1.29x + -10.86

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 4 Alternate Solution using functions</b></div>

# %%
def slope(point1, point2):
  """
  Calculates the slope of a line given two points.

  Args:
    point1: A tuple of the coordinates of the first point.
    point2: A tuple of the coordinates of the second point.

  Returns:
    The slope of the line.
  """

  x1, y1 = point1
  x2, y2 = point2
  return round((y2 - y1) / (x2 - x1),2)

def y_intercept(point1, slope):
  """
  Calculates the y-intercept of a line given a point and the slope.

  Args:
    point1: A tuple of the coordinates of the point.
    slope: The slope of the line.

  Returns:
    The y-intercept of the line.
  """

  x, y = point1
  return round(y - slope * x,2) 

def slope_intercept_form(point1, slope):
  """
  Calculates the slope-intercept form of the equation of a line given a point and the slope.

  Args:
    point1: A tuple of the coordinates of the point.
    slope: The slope of the line.

  Returns:
    The slope-intercept form of the equation of the line.
  """

  y_intercept_val = y_intercept(point1, slope)
  return "y = " + str(slope) + "x + " + str(y_intercept_val)

if __name__ == "__main__":
  point1 = (3, -7)
  point2 = (10, 2)
  slope = slope(point1, point2)
  y_intercept_val = y_intercept(point1, slope)
  equation = slope_intercept_form(point1, slope)
  print("Slope: " + str(slope))
  print("Y-intercept: " + str(y_intercept_val))
  print("Equation: " + equation)
# Out:
# Slope: 1.29
# Y-intercept: -10.87
# Equation: y = 1.29x + -10.87

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 9:</b></div>
#
# Solve the system of equations by graphing:
#
# $$ -x + y = 4 $$
# $$ 6x + 3y = -6 $$

# %% [markdown]
# Plotting equations

# %%
import matplotlib.pyplot as plt

# Equation 1: -x + y = 4
# We can rewrite this equation as y = x + 4

# Equation 2: 6x + 3y = -6
# We can rewrite this equation as y = (-6 - 6x) / 3 or y = -2 - 2x

# Define the equations as functions
def equation_1(x):
    return x + 4

def equation_2(x):
    return -2 - 2*x

# Generate x values for plotting
x_values = list(range(-10, 11))

# Calculate corresponding y values for each equation
y_values_eq1 = [equation_1(x) for x in x_values]
y_values_eq2 = [equation_2(x) for x in x_values]

# Plot the two lines
plt.plot(x_values, y_values_eq1, label='-x + y = 4')
plt.plot(x_values, y_values_eq2, label='6x + 3y = -6')

# Set labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graphical Solution of the System of Equations')

# Add a legend
plt.legend()

# Show the plot
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# %% [markdown]
# Solving system of equations

# %%
import sympy as sym
# Use sympy package to display the equation
sym.init_printing()
#sym.solve()
x,y = sym.symbols('x,y')

solns = sym.solve([
    -x + y - 4 , 
    6*x + 3*y + 6],
    [x, y])
print(f"{solns[x]} is supposed to be -2")
print(f"{solns[y]} is supposed to be 2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import sympy as sym
#       2 # Use sympy package to display the equation
#       3 sym.init_printing()
#
# ModuleNotFoundError: No module named 'sympy'

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 10:</b></div>
#
# Solve the system of equations:
#
# $$ 3x - 6y = 9 $$
# $$ -2x + 5y = -8 $$

# %%
import sympy as sym
# Use sympy package to display the equation
sym.init_printing()
#sym.solve()
x,y = sym.symbols('x,y')

solns = sym.solve([
    3*x - 6*y - 9 , 
    -2*x + 5*y + 8],
    [x, y])
print(f"{solns[x]} is supposed to be -1")
print(f"{solns[y]} is supposed to be -2")
# Out:
# -1 is supposed to be -1
# -2 is supposed to be -2

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 11:</b></div>
#
# In 1982, the US Mint changed the composition of pennies from all copper to zinc with copper coating. Pennies made prior to 1982 weigh 3.1 grams. Pennies made since 1982 weighed 2.5 grams.
# Suppose you have a bag of 1332 pennies, and the bag weighs 3715.2 grams.
#
# Let $x$ represent the number of pennies made prior to 1982 and let $y$ represent the number of pennies made after 1982. Set up the system of equations.

# %%
import sympy as sym
# Use sympy package to display the equation
sym.init_printing()

x,y = sym.symbols('x,y')

# System of equations 
# x + y = 1332
# 3.1x + 2.5y = 3715.2
solns = sym.solve([
    x + y - 1332 , 
    3.1*x + 2.5*y - 3715.2],
    [x, y])
print(f"{round(solns[x])} is supposed to be 642")
print(f"{round(solns[y])} is supposed to be 690")
# Out:
# 642 is supposed to be 642
# 690 is supposed to be 690

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 12:</b></div>
#
# Alphonso goes to a fast food restaurant and orders some tacos and burritos. He sees on the nutrition menu that tacos are 210 calories and burritos are 580 calories. Suppose he ordered 3 items and consumed a total of 1370 calories.
#
# Let $t$ be the number of tacos eaten and let $b$ be the number of burritos eaten. Set up the system of equations.
#
# Write the equation for the total number of tacos and burritos eaten.

# %%
import sympy as sym
# Use sympy package to display the equation
sym.init_printing()

t,b = sym.symbols('t,b')

# System of equations 
# t + b = 3
# 210t + 580b = 1370
solns = sym.solve([
    t + b - 3 , 
    210*t + 580*b - 1370],
    [t, b])
print(f"Number of tacos:    {round(solns[t])}")
print(f"Number of burritos: {round(solns[b])}")
# Out:
# Number of tacos:    1
# Number of burritos: 2

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 14:</b></div>
#
# Consider the system of linear equations
#
# $5x - 5y = -1$
#
# $-x + 3y = 1$
#
# Find the solution to the system.

# %%
import sympy as sym
# Use sympy package to display the equation
sym.init_printing()

x,y,z = sym.symbols('x,y,z')

solns = sym.solve([
    5*x - 5*y + 1, 
    -x + 3*y - 1
    ],
    [x, y])

print(f"x = {round(solns[x],1)}")
print(f"y = {round(solns[y],1)}")
# Out:
# x = 0.2
# y = 0.4
