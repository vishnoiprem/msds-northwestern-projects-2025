# %%
import numpy as np

# %%
np.log(4.3)+(2+95)/(2+2.3)
# Out:
# np.float64(24.016754557583237)

# %%
def log_data(t):
    log_t= np.log(t+2.3) + (t+95)/(t+2.3)
    return log_t

# %%
log_data(5)
# Out:
# np.float64(15.686504485140647)

# %%
log_data(10)
# Out:
# np.float64(11.04618462823203)

# %%
log_data(0)
# Out:
# np.float64(42.13725694902207)
